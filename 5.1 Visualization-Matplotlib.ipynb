# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.style.available
# Out:
# ['_classic_test',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# # 1. Hist Plot - tips to use the bins for statistics

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]

# %%
# plt.hist(ages, bins = 5, edgecolor = 'black')

# %%
pd.__version__
# Out:
# '0.24.2'

# %%
median_age = 29

# %%
color = '#fc4f30'

# %%
 use Bins from a list to display he data distribution
plt.hist(ages, bins = [10,20,30,40,50], edgecolor = 'black', log = True)

# show the median value in the plot iusing plt.axvline - Axis Virtual Line
plt.axvline(median_age, color = color, label = 'Age Median')

# plt.set_title('Ages of Respondents')
#p lt.set_xlabel('Ages')
# plt.set_ylabel('Totoal numbers')
plt.title ='Ages of Respondents'
plt.xlabel = 'Ages'
plt.ylabel ='Total number'

plt.legend()

# %%
plt.tight_layout
# Out:
# True

# %% [markdown]
# # 2. Scatter Plots

# %%
# use Seanborn style
plt.style.use('seaborn')

# %%
x = [5,7,8,5,6,7,9,2,3,4,4,4,2,6,3,6,8,6,4,1]

# %%
y = [7,4,3,9,1,3,2,5,2,4,8,1,6,4,9,7,7,5,1,5]

# %%
colors = [7,5,9,7,5,7,2,5,3,7,1,2,8,1,9,2,5,6,7,5]

# %%
sizes = [209, 486,381,255, 191, 315, 185, 228, 174, 
        538, 239, 399, 153, 273, 293, 436, 601, 397, 539, 530]

# %%
plt.tight_layout = True

# %%
plt.scatter(x, y, s=200, c = 'green') # x, y, s (for size of the dots), c for color

# %%
plt.scatter(x,y,sizes, color = 'blue', edgecolor = 'black', linewidth = 1, alpha=0.75)

# %%
plt.scatter(x,y,sizes, c = colors, edgecolor = 'black', linewidth = 1, alpha=0.75)

# %%
plt.scatter(x,y,sizes, c = colors, cmap ='Greens',edgecolor = 'black', linewidth = 1, alpha=0.75) # cmap as 底色

cbar = plt.colorbar()   # ths cbar sector has to be put to same plt plot cell in Jupyter notebook, otherwise it does not show
cbar.set_label('satisfaction')

# %%
# here color can be from a seperate series, e.g. from ibe corssponding Panda Data column

plt.scatter(x,y,sizes, c = colors, cmap ='Reds',edgecolor = 'Blue', linewidth = 1, alpha=0.75) # cmap as 底色 for cbar

cbar = plt.colorbar()   # ths cbar sector has to be put to same plt plot cell in Jupyter notebook, otherwise it does not show
cbar.set_label('satisfaction')

# %% [markdown]
# # 3 Basic Line char, Bar chart, and BarH chart & stackplot

# %% [markdown]
# ## #stackplot

# %%
import numpy as np

# %%
plt.style.use('seaborn')

# %%
x =[1, 2, 3, 4, 5, 6 ,7]
y1 = np.random.randint(1, 10,size = 7)
y2 = np.random.randint(1, 20, size =7)
y3 = np.random.randint(1, 8, size =7)

color = ['green', 'blue', 'red']
labels = ['Value - y1', 'Value - y2', 'Value - y3']

# %%
plt.stackplot(x, y1, y2, y3,  colors = color, labels = labels, alpha = 0.8)

# plt.set_title('Stackplot trail title') ## why set title and x/y labels does not work here???
# plt.set_xlabel('x-label')
# plt.set_ylabel('y-label')

plt.legend()

# %% [markdown]
# # 4. plot time seiries data

# %%
plt.style.use('seaborn')
import numpy as np
import pandas as pd
# from datetime import datetime, timedate
from matplotlib import pyplot as plt
# from matplotlib import dates as mpl_dates

# %%
date_str = [
    '2019-05-24',
    '2019-05-26',
    '2019-05-23',
    '2019-05-27',
    '2019-05-28',
    '2019-05-29',
    '2019-05-30',
     '2019-05-25'
]

# %%
type(date_str)
# Out:
# list

# %%
date_time =  pd.to_datetime(date_str)

# %%
type(date_time)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
date_time
# Out:
# DatetimeIndex(['2019-05-24', '2019-05-26', '2019-05-23', '2019-05-27',
#                '2019-05-28', '2019-05-29', '2019-05-30', '2019-05-25'],
#               dtype='datetime64[ns]', freq=None)

# %%
plt.plot(date_time, y, color = 'red', marker='o', linestyle ='--', linewidth = 2)

# %%
date_time = date_time.sort_values() # looks like inplace = true is not supported, so just use "=" to overwrite the series

# %%
date_time
# Out:
# DatetimeIndex(['2019-05-23', '2019-05-24', '2019-05-25', '2019-05-26',
#                '2019-05-27', '2019-05-28', '2019-05-29', '2019-05-30'],
#               dtype='datetime64[ns]', freq=None)

# %%
y = [0,1, 2, 3, 4, 5, 6, 7]

# %%
plt.plot(date_time, y, color = 'red', marker='o', linestyle ='--', linewidth = 2)

# %%
plt.plot_date(date_time, y, color = 'green', linestyle ='solid')

# %%
# plt.style.use('fivethirtyeight')
plt.style.use('ggplot')

# %%
plt.gcf().autofmt_xdate()

# %%
### date_format = '%d-%m-%y%' # need to check seperately how format string can be formulated

# %%
### plt.gca().xaxis.set_major_formatter(date_format) # gca = get current axix

# %%
plt.tight_layout
# Out:
# True

# %%
plt.plot(date_time, y, color = 'red', marker='o', linestyle ='--', linewidth = 2)

# %% [markdown]
# # 5. plot real time data using matplotlib.animation FuncAnimation
# ## need to double check why it is not working here!!

# %%
import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation  ## animation in matplotlib
# %matplotlib inline

# %%
plt.style.use('fivethirtyeight')

# %%
x_vals =[0,1,2,3,4,5]
y_vals =[0,1,2,3,4,5]

# %%
plt.plot(x_vals, y_vals)

# %%
index = count()

# %%
def animate(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(0, 5))
    plt.cla()  # clear the clear th current axes 
    plt.plot(x_vals, y_vals)

# %%
ani = FuncAnimation(plt.gcf(), animate, interval = 100)   # not working with Jupyter notebook but Pycharm??? (gcf = get current function)

# %% [markdown]
# # 6. sub plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# plt.gcf() # get current figure

# %%
# plt.gca() # get current axis

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 2, ncols =1, sharex = True) # sharex, there is also sherey : one fig, two plots

# %%
print(ax)

# %%
x= [1, 2, 3]
y= [6, 9, 3]

# %%
ax1.plot(x, y)  # why this does not work???

# %%
plt.plot(x,y)

# %%
fig1, ax3 = plt.subplots()
fig2, ax4 = plt.subplots() ## fig可以理解成画板 can adopt multiple figs to plot

# %%
x= [1, 2, 3]
y= [6, 9, 3]

# %%
ax3.plot(x, y)
