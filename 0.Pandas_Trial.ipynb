# %% [markdown]
# # Pandas Dateframe General

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
m = np.random.randint(100,size=(20,2)) #Generate matrix (array, stating from 100, 20x2)

# %%
rng = pd.date_range(start='2016-01-01',periods = 20,freq = 'M')
rng
# Out:
# DatetimeIndex(['2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31',
#                '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31',
#                '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
df = pd.DataFrame(m,columns=['revenue','cost'],index = rng)
df
# Out:
#             revenue  cost
# 2016-01-31       67    29
# 2016-02-29       29    81
# 2016-03-31       12    82
# 2016-04-30       94    15
# 2016-05-31       24     8
# 2016-06-30       10    12
# 2016-07-31       61    41
# 2016-08-31        0    34
# 2016-09-30       76    23
# 2016-10-31       53    77
# 2016-11-30       40    42
# 2016-12-31       20    11
# 2017-01-31       89    62
# 2017-02-28       54     5
# 2017-03-31       44    33
# 2017-04-30       22    21
# 2017-05-31       92    59
# 2017-06-30       11    64
# 2017-07-31       36    66
# 2017-08-31       33     7

# %%
df.index
# Out:
# DatetimeIndex(['2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31',
#                '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31',
#                '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
df.shape
# Out:
# (20, 2)

# %%
#df.info

# %%
df.columns
# Out:
# Index(['revenue', 'cost'], dtype='object')

# %%
df.head()
df.tail()
# Out:
#             revenue  cost
# 2017-04-30       22    21
# 2017-05-31       92    59
# 2017-06-30       11    64
# 2017-07-31       36    66
# 2017-08-31       33     7

# %%
df[['revenue','cost']].head()
# Out:
#             revenue  cost
# 2016-01-31       67    29
# 2016-02-29       29    81
# 2016-03-31       12    82
# 2016-04-30       94    15
# 2016-05-31       24     8

# %%
df.reset_index(inplace=True)

# %%
df.columns
# Out:
# Index(['index', 'revenue', 'cost'], dtype='object')

# %%
df.loc[:,['index','revenue','cost']]
# Out:
#         index  revenue  cost
# 0  2016-01-31       67    29
# 1  2016-02-29       29    81
# 2  2016-03-31       12    82
# 3  2016-04-30       94    15
# 4  2016-05-31       24     8
# 5  2016-06-30       10    12
# 6  2016-07-31       61    41
# 7  2016-08-31        0    34
# 8  2016-09-30       76    23
# 9  2016-10-31       53    77
# 10 2016-11-30       40    42
# 11 2016-12-31       20    11
# 12 2017-01-31       89    62
# 13 2017-02-28       54     5
# 14 2017-03-31       44    33
# 15 2017-04-30       22    21
# 16 2017-05-31       92    59
# 17 2017-06-30       11    64
# 18 2017-07-31       36    66
# 19 2017-08-31       33     7

# %%
df.iloc[0:2,0:3]
# Out:
#        index  revenue  cost
# 0 2016-01-31       67    29
# 1 2016-02-29       29    81

# %%
df.iloc[1,2]
# Out:
# 81

# %%
df.index = df['index']

# %%
df.columns
# Out:
# Index(['revenue', 'cost'], dtype='object')

# %%
df.head()
# Out:
#             revenue  cost
# index
# 2016-01-31       67    29
# 2016-02-29       29    81
# 2016-03-31       12    82
# 2016-04-30       94    15
# 2016-05-31       24     8

# %%
df.columns
# Out:
# Index(['index', 'revenue', 'cost'], dtype='object')

# %%
df.head()
# Out:
#             revenue  cost
# index
# 2016-01-31       67    29
# 2016-02-29       29    81
# 2016-03-31       12    82
# 2016-04-30       94    15
# 2016-05-31       24     8

# %%
df['2016']
# Out:
#             revenue  cost
# index
# 2016-01-31       67    29
# 2016-02-29       29    81
# 2016-03-31       12    82
# 2016-04-30       94    15
# 2016-05-31       24     8
# 2016-06-30       10    12
# 2016-07-31       61    41
# 2016-08-31        0    34
# 2016-09-30       76    23
# 2016-10-31       53    77
# 2016-11-30       40    42
# 2016-12-31       20    11

# %%
df['2016-08']
# Out:
#             revenue  cost
# index
# 2016-08-31        0    34

# %%
df['2016':'2017-02']
# Out:
#             revenue  cost
# index
# 2016-01-31       67    29
# 2016-02-29       29    81
# 2016-03-31       12    82
# 2016-04-30       94    15
# 2016-05-31       24     8
# 2016-06-30       10    12
# 2016-07-31       61    41
# 2016-08-31        0    34
# 2016-09-30       76    23
# 2016-10-31       53    77
# 2016-11-30       40    42
# 2016-12-31       20    11
# 2017-01-31       89    62
# 2017-02-28       54     5

# %%
df['profit']=df.revenue -  df.cost

# %%
df.head()
# Out:
#             revenue  cost  profit
# index
# 2016-01-31       67    29      38
# 2016-02-29       29    81     -52
# 2016-03-31       12    82     -70
# 2016-04-30       94    15      79
# 2016-05-31       24     8      16

# %%
df.loc['2016':'2017',['profit']]
# Out:
#             profit
# index
# 2016-01-31      38
# 2016-02-29     -52
# 2016-03-31     -70
# 2016-04-30      79
# 2016-05-31      16
# 2016-06-30      -2
# 2016-07-31      20
# 2016-08-31     -34
# 2016-09-30      53
# 2016-10-31     -24
# 2016-11-30      -2
# 2016-12-31       9
# 2017-01-31      27
# 2017-02-28      49
# 2017-03-31      11
# 2017-04-30       1
# 2017-05-31      33
# 2017-06-30     -53
# 2017-07-31     -30
# 2017-08-31      26

# %%
df.iloc[:5,:2]
# Out:
#             revenue  cost
# index
# 2016-01-31       67    29
# 2016-02-29       29    81
# 2016-03-31       12    82
# 2016-04-30       94    15
# 2016-05-31       24     8

# %%
# df[['2016-01-31'],['revenue']] -- this does not work, have to use .loc function

# %%
df.loc['2016-01-31','revenue']=80

# %%
df.head()
# Out:
#             revenue  cost  profit  (2016-01-31, revenue)
# index
# 2016-01-31       80    29      38                     80
# 2016-02-29       29    81     -52                     80
# 2016-03-31       12    82     -70                     80
# 2016-04-30       94    15      79                     80
# 2016-05-31       24     8      16                     80

# %%
df.iloc[:,:-1]
# Out:
#             revenue  cost  profit
# index
# 2016-01-31       80    29      38
# 2016-02-29       29    81     -52
# 2016-03-31       12    82     -70
# 2016-04-30       94    15      79
# 2016-05-31       24     8      16
# 2016-06-30       10    12      -2
# 2016-07-31       61    41      20
# 2016-08-31        0    34     -34
# 2016-09-30       76    23      53
# 2016-10-31       53    77     -24
# 2016-11-30       40    42      -2
# 2016-12-31       20    11       9
# 2017-01-31       89    62      27
# 2017-02-28       54     5      49
# 2017-03-31       44    33      11
# 2017-04-30       22    21       1
# 2017-05-31       92    59      33
# 2017-06-30       11    64     -53
# 2017-07-31       36    66     -30
# 2017-08-31       33     7      26

# %%
df = df.iloc[:,:-1] // wonderful way to del a column!!

# %%
df.head()
# Out:
#             revenue  cost  profit
# index
# 2016-01-31       80    29      38
# 2016-02-29       29    81     -52
# 2016-03-31       12    82     -70
# 2016-04-30       94    15      79
# 2016-05-31       24     8      16

# %%
df['2017-01-31':'2017-02-01'][['revenue']]
# Out:
#             revenue
# index
# 2017-01-31      100

# %%
df.loc['2017-01-31',['revenue']] = 200

# %%
df.loc['2017-01-31',['revenue']]
# Out:
# revenue    200
# Name: 2017-01-31 00:00:00, dtype: int32

# %%
df['2017'].head()
# Out:
#             revenue  cost  profit
# index
# 2017-01-31      200    62      27
# 2017-02-28       54     5      49
# 2017-03-31       44    33      11
# 2017-04-30       22    21       1
# 2017-05-31       92    59      33

# %%
df.iloc[2] # though index as data range here,  iloc with integer still works
# Out:
# revenue    12
# cost       82
# profit    -70
# Name: 2016-03-31 00:00:00, dtype: int32

# %%
df[df['profit']>=0][['cost','profit']]
# Out:
#             cost  profit
# index
# 2016-01-31    29      38
# 2016-04-30    15      79
# 2016-05-31     8      16
# 2016-07-31    41      20
# 2016-09-30    23      53
# 2016-12-31    11       9
# 2017-01-31    62      27
# 2017-02-28     5      49
# 2017-03-31    33      11
# 2017-04-30    21       1
# 2017-05-31    59      33
# 2017-08-31     7      26

# %%
df[df['profit']>=0][['cost','profit']]
# Out:
#             cost  profit
# index
# 2016-01-31    29      38
# 2016-04-30    15      79
# 2016-05-31     8      16
# 2016-07-31    41      20
# 2016-09-30    23      53
# 2016-12-31    11       9
# 2017-01-31    62      27
# 2017-02-28     5      49
# 2017-03-31    33      11
# 2017-04-30    21       1
# 2017-05-31    59      33
# 2017-08-31     7      26

# %%
df[df['profit']<=0]
# Out:
#             revenue  cost  profit profit_cat
# index
# 2016-02-29       29    81     -52   Negative
# 2016-03-31       12    82     -70   Negative
# 2016-06-30       10    12      -2   Negative
# 2016-08-31        0    34     -34   Negative
# 2016-10-31       53    77     -24   Negative
# 2016-11-30       40    42      -2   Negative
# 2017-06-30       11    64     -53   Negative
# 2017-07-31       36    66     -30   Negative

# %%
df[df['profit']<=0]
# Out:
#             revenue  cost  profit profit_cat
# index
# 2016-02-29       29    81     -52   Negative
# 2016-03-31       12    82     -70   Negative
# 2016-06-30       10    12      -2   Negative
# 2016-08-31        0    34     -34   Negative
# 2016-10-31       53    77     -24   Negative
# 2016-11-30       40    42      -2   Negative
# 2017-06-30       11    64     -53   Negative
# 2017-07-31       36    66     -30   Negative

# %%
df['2016'].profit >0
# Out:
# index
# 2016-01-31     True
# 2016-02-29    False
# 2016-03-31    False
# 2016-04-30     True
# 2016-05-31     True
# 2016-06-30    False
# 2016-07-31     True
# 2016-08-31    False
# 2016-09-30     True
# 2016-10-31    False
# 2016-11-30    False
# 2016-12-31     True
# Name: profit, dtype: bool

# %%
plt.plot(df.profit)

# %%
df[(df['profit']>=0)& (df['cost']>=50)][['cost','profit','revenue']]
# Out:
#             cost  profit  revenue
# index
# 2017-01-31    62      27      200
# 2017-05-31    59      33       92

# %%
df.loc['2016',['profit','revenue']]
# Out:
#             profit  revenue
# index
# 2016-01-31      38       80
# 2016-02-29     -52       29
# 2016-03-31     -70       12
# 2016-04-30      79       94
# 2016-05-31      16       24
# 2016-06-30      -2       10
# 2016-07-31      20       61
# 2016-08-31     -34        0
# 2016-09-30      53       76
# 2016-10-31     -24       53
# 2016-11-30      -2       40
# 2016-12-31       9       20

# %%
len(df.index)
len(df.columns)
df.shape
# Out:
# (20, 3)

# %%
df[df['profit']<=0][['revenue','cost']]
# Out:
#             revenue  cost
# index
# 2016-02-29       29    81
# 2016-03-31       12    82
# 2016-06-30       10    12
# 2016-08-31        0    34
# 2016-10-31       53    77
# 2016-11-30       40    42
# 2017-06-30       11    64
# 2017-07-31       36    66

# %%
df[:5]
# Out:
#             revenue  cost  profit
# index
# 2016-01-31       80    29      38
# 2016-02-29       29    81     -52
# 2016-03-31       12    82     -70
# 2016-04-30       94    15      79
# 2016-05-31       24     8      16

# %% [markdown]
# ### how to update selected columns

# %%
df_new= df[df['profit']> 0]

# %%
df[df['profit']> 0].loc[:,['profit_cat']] = '100' # why this syntax can operate but result not expected ???

# %%
bool_series = df['profit']> 0

# %%
bool_series.head()
# Out:
# index
# 2016-01-31     True
# 2016-02-29    False
# 2016-03-31    False
# 2016-04-30     True
# 2016-05-31     True
# Name: profit, dtype: bool

# %%
df.loc[bool_series,'profit_cat'] = 'Positive'

# %%
df.loc[~ bool_series,'profit_cat'] = 'Negative'

# %%
df.loc[df['profit']> 0,'profit_cat'] = 'New_Try' ## update col, slicing rows matching conditions

# %%
df
# Out:
#             revenue  cost  profit profit_cat
# index
# 2016-01-31       80    29      38    New_Try
# 2016-02-29       29    81     -52   Negative
# 2016-03-31       12    82     -70   Negative
# 2016-04-30       94    15      79    New_Try
# 2016-05-31       24     8      16    New_Try
# 2016-06-30       10    12      -2   Negative
# 2016-07-31       61    41      20    New_Try
# 2016-08-31        0    34     -34   Negative
# 2016-09-30       76    23      53    New_Try
# 2016-10-31       53    77     -24   Negative
# 2016-11-30       40    42      -2   Negative
# 2016-12-31       20    11       9    New_Try
# 2017-01-31      200    62      27    New_Try
# 2017-02-28       54     5      49    New_Try
# 2017-03-31       44    33      11    New_Try
# 2017-04-30       22    21       1    New_Try
# 2017-05-31       92    59      33    New_Try
# 2017-06-30       11    64     -53   Negative
# 2017-07-31       36    66     -30   Negative
# 2017-08-31       33     7      26    New_Try

# %%
df.profit_cat.count()
df.profit_cat.value_counts()
# Out:
# New_Try     12
# Negative     8
# Name: profit_cat, dtype: int64

# %% [markdown]
# ### Pivot & Pivot_Table

# %%
df.T
# Out:
# index      2016-01-31 2016-02-29 2016-03-31 2016-04-30 2016-05-31 2016-06-30  \
# revenue            80         29         12         94         24         10
# cost               29         81         82         15          8         12
# profit             38        -52        -70         79         16         -2
# profit_cat   Positive   Negative   Negative   Positive   Positive   Negative
#
# index      2016-07-31 2016-08-31 2016-09-30 2016-10-31 2016-11-30 2016-12-31  \
# revenue            61          0         76         53         40         20
# cost               41         34         23         77         42         11
# profit             20        -34         53        -24         -2          9
# profit_cat   Positive   Negative   Positive   Negative   Negative   Positive
#
# index      2017-01-31 2017-02-28 2017-03-31 2017-04-30 2017-05-31 2017-06-30  \
# revenue           200         54         44         22         92         11
# ...

# %%
df.head()
# Out:
#             revenue  cost  profit profit_cat
# index
# 2016-01-31       80    29      38    New_Try
# 2016-02-29       29    81     -52   Negative
# 2016-03-31       12    82     -70   Negative
# 2016-04-30       94    15      79    New_Try
# 2016-05-31       24     8      16    New_Try

# %%
df.profit_cat.value_counts()
# Out:
# New_Try     12
# Negative     8
# Name: profit_cat, dtype: int64

# %%
pd.crosstab

# %% [markdown]
# # Date Time series playing around

# %%
df.head()
# Out:
#             revenue  cost  profit profit_cat
# index
# 2016-01-31       80    29      38    New_Try
# 2016-02-29       29    81     -52   Negative
# 2016-03-31       12    82     -70   Negative
# 2016-04-30       94    15      79    New_Try
# 2016-05-31       24     8      16    New_Try

# %%
df_d = df.asfreq(freq='D',method='pad')
df_d.head()
# Out:
#             revenue  cost  profit
# index
# 2016-01-31       80    29      38
# 2016-02-01       80    29      38
# 2016-02-02       80    29      38
# 2016-02-03       80    29      38
# 2016-02-04       80    29      38

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
ufo.Time.str.slice(-5, -3).astype(int).head() # tr function, and slice function, astype function
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int32

# %%
ufo['Time'] =  pd.to_datetime(ufo.Time)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
ufo.Time.dt.weekofyear.head()
# Out:
# 0    22
# 1    27
# 2     7
# 3    23
# 4    16
# Name: Time, dtype: int64

# %%
ufo.Time.dt.dayofyear.head()
# Out:
# 0    152
# 1    181
# 2     46
# 3    152
# 4    108
# Name: Time, dtype: int64

# %%
ts = pd.to_datetime('1/1/1999')

# %%
ufo.loc[ufo.Time >=ts,:].head()
# Out:
#                     City Colors Reported Shape Reported State  \
# 12832          Loma Rica             NaN          LIGHT    CA
# 12833            Bauxite             NaN            NaN    AR
# 12834           Florence             NaN       CYLINDER    SC
# 12835       Lake Henshaw             NaN          CIGAR    CA
# 12836  Wilmington Island             NaN          LIGHT    GA
#
#                      Time
# 12832 1999-01-01 02:30:00
# 12833 1999-01-01 03:00:00
# 12834 1999-01-01 14:00:00
# 12835 1999-01-01 15:00:00
# 12836 1999-01-01 17:15:00

# %%
(ufo.Time.max()- ufo.Time.min()).days
# Out:
# 25781

# %%
ufo['year']= ufo.Time.dt.year

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
ufo.year.value_counts().sort_index().head()
# Out:
# 1930    2
# 1931    2
# 1933    1
# 1934    1
# 1935    1
# Name: Time, dtype: int64

# %%
ufo.year.value_counts().sort_index().plot()

# %%
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State                Time  \
# 18236   Grant Park             NaN       TRIANGLE    IL 2000-12-31 23:00:00
# 18237  Spirit Lake             NaN           DISK    IA 2000-12-31 23:00:00
# 18238  Eagle River             NaN            NaN    WI 2000-12-31 23:45:00
# 18239  Eagle River             RED          LIGHT    WI 2000-12-31 23:45:00
# 18240         Ybor             NaN           OVAL    FL 2000-12-31 23:59:00
#
#        year
# 18236  2000
# 18237  2000
# 18238  2000
# 18239  2000
# 18240  2000
